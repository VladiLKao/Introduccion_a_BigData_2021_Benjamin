# %%
##ARTISTAS

# %%
import pandas as pd
df = pd.read_csv("data_by_artist.csv")
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ## 10 valores ordenados de mayor a menor

# %%
df = df.head(10).sort_values(by='artists', ascending=True)

# %%
df['artists']
# Out:
# 0                     "Cats" 1981 Original London Cast
# 1                            "Cats" 1983 Broadway Cast
# 2          "Fiddler On The Roof” Motion Picture Chorus
# 3       "Fiddler On The Roof” Motion Picture Orchestra
# 4    "Joseph And The Amazing Technicolor Dreamcoat"...
# 5    "Joseph And The Amazing Technicolor Dreamcoat"...
# 6                               "Mama" Helen Teagarden
# 7                              "Test for Victor Young"
# 8                                  "Weird Al" Yankovic
# 9                                               $0dg0d
# Name: artists, dtype: object

# %% [markdown]
# ## datos relacionados

# %%
df
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.598500
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
# 5  "Joseph And The Amazing Technicolor Dreamcoat"...      0.591167
# 6                             "Mama" Helen Teagarden      0.725000
# 7                            "Test for Victor Young"      0.927000
# 8                                "Weird Al" Yankovic      0.186821
# 9                                             $0dg0d      0.110000
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.470100  267072.000000  0.376203          0.010261  0.283050
# 1      0.441731  287280.000000  0.406808          0.081158  0.315215
# ...

# %%
relacion = df[['artists','instrumentalness','liveness','popularity']]

# %%
relacion.head(10)
# Out:
#                                              artists  instrumentalness  \
# 0                   "Cats" 1981 Original London Cast          0.010261
# 1                          "Cats" 1983 Broadway Cast          0.081158
# 2        "Fiddler On The Roof” Motion Picture Chorus          0.024593
# 3     "Fiddler On The Roof” Motion Picture Orchestra          0.073587
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...          0.009400
# 5  "Joseph And The Amazing Technicolor Dreamcoat"...          0.007042
# 6                             "Mama" Helen Teagarden          0.186000
# 7                            "Test for Victor Young"          0.076200
# 8                                "Weird Al" Yankovic          0.000045
# 9                                             $0dg0d          0.000009
#
#    liveness  popularity
# 0  0.283050   38.200000
# 1  0.315215   31.538462
# 2  0.325786   34.571429
# 3  0.275481   34.407407
# 4  0.195000   42.000000
# 5  0.176067   33.166667
# ...

# %%
relacion = df[['artists','tempo','key','count']]

# %%
relacion.head(10)
# Out:
#                                              artists       tempo  key  count
# 0                   "Cats" 1981 Original London Cast  114.128800    5     10
# 1                          "Cats" 1983 Broadway Cast  103.044154    5     26
# 2        "Fiddler On The Roof” Motion Picture Chorus   77.375857    0      7
# 3     "Fiddler On The Roof” Motion Picture Orchestra   88.667630    0     27
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...  122.835857    5      7
# 5  "Joseph And The Amazing Technicolor Dreamcoat"...  122.517833    9     24
# 6                             "Mama" Helen Teagarden  134.819000    8      2
# 7                            "Test for Victor Young"  132.788000   10      2
# 8                                "Weird Al" Yankovic  132.876604    9    106
# 9                                             $0dg0d  141.948000    7      2

# %%
df.corr
# Out:
# <bound method DataFrame.corr of                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.598500
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
# 5  "Joseph And The Amazing Technicolor Dreamcoat"...      0.591167
# 6                             "Mama" Helen Teagarden      0.725000
# 7                            "Test for Victor Young"      0.927000
# 8                                "Weird Al" Yankovic      0.186821
# 9                                             $0dg0d      0.110000
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.470100  267072.000000  0.376203          0.010261  0.283050
# ...

# %%
relacion.describe()
# Out:
#             tempo        key       count
# count   10.000000  10.000000   10.000000
# mean   117.100173   5.800000   21.300000
# std     21.295424   3.552777   31.429109
# min     77.375857   0.000000    2.000000
# 25%    105.815315   5.000000    3.250000
# 50%    122.676845   6.000000    8.500000
# 75%    132.854453   8.750000   25.500000
# max    141.948000  10.000000  106.000000

# %%
df.describe()
# Out:
#        acousticness  danceability    duration_ms     energy  instrumentalness  \
# count     10.000000     10.000000      10.000000  10.000000         10.000000
# mean       0.625324      0.539046  232485.356808   0.460544          0.046830
# std        0.288858      0.137067   61565.483367   0.182680          0.058994
# min        0.110000      0.348286  135533.000000   0.245770          0.000009
# 25%        0.530827      0.448084  186357.990566   0.319507          0.007632
# 50%        0.661750      0.477217  240697.731481   0.440404          0.017427
# 75%        0.861047      0.647344  269595.107143   0.506071          0.075547
# max        0.927000      0.734000  328920.000000   0.822000          0.186000
#
#         liveness   loudness  speechiness       tempo    valence  popularity  \
# count  10.000000  10.000000    10.000000   10.000000  10.000000   10.000000
# mean    0.304853 -13.104775     0.153385  117.100173   0.555244   24.975189
# ...

# %% [markdown]
# ## Varianza

# %%
var = df.var()

# %%
print(var)
# Out:
# acousticness        8.343874e-02
# danceability        1.878744e-02
# duration_ms         3.790309e+09
# energy              3.337188e-02
# instrumentalness    3.480239e-03
# liveness            3.060404e-02
# loudness            2.121321e+01
# speechiness         3.322773e-03
# tempo               4.534951e+02
# valence             5.820758e-02
# popularity          2.831884e+02
# key                 1.262222e+01
# mode                1.000000e-01
# count               9.877889e+02
# dtype: float64

# %% [markdown]
# ## Moda

# %%
moda= df.mode ()

# %%
print (moda)
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.110000
# 1                          "Cats" 1983 Broadway Cast      0.186821
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.510714
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.591167
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.598500
# 5  "Joseph And The Amazing Technicolor Dreamcoat"...      0.725000
# 6                             "Mama" Helen Teagarden      0.856571
# 7                            "Test for Victor Young"      0.862538
# 8                                "Weird Al" Yankovic      0.884926
# 9                                             $0dg0d      0.927000
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.348286  135533.000000  0.245770          0.000009  0.154000
# 1      0.425074  160171.000000  0.286571          0.000045  0.160926
# ...

# %% [markdown]
# ## Promedio

# %%
Prom = df.mean ()

# %%
print (Prom)
# Out:
# acousticness             0.625324
# danceability             0.539046
# duration_ms         232485.356808
# energy                   0.460544
# instrumentalness         0.046830
# liveness                 0.304853
# loudness               -13.104775
# speechiness              0.153385
# tempo                  117.100173
# valence                  0.555244
# popularity              24.975189
# key                      5.800000
# mode                     0.900000
# count                   21.300000
# dtype: float64

# %% [markdown]
# ## Mediana

# %%
m = df.median ()

# %%
print (m)
# Out:
# acousticness             0.661750
# danceability             0.477217
# duration_ms         240697.731481
# energy                   0.440404
# instrumentalness         0.017427
# liveness                 0.279266
# loudness               -12.562150
# speechiness              0.139100
# tempo                  122.676845
# valence                  0.453393
# popularity              33.017296
# key                      6.000000
# mode                     1.000000
# count                    8.500000
# dtype: float64

# %% [markdown]
# ## Minimo

# %%
mini = df.min ()

# %%
print (mini)
# Out:
# artists             "Cats" 1981 Original London Cast
# acousticness                                    0.11
# danceability                                0.348286
# duration_ms                                   135533
# energy                                       0.24577
# instrumentalness                            9.05e-06
# liveness                                       0.154
# loudness                                     -20.615
# speechiness                                0.0822755
# tempo                                        77.3759
# valence                                     0.268865
# popularity                                         0
# key                                                0
# mode                                               0
# count                                              2
# dtype: object

# %% [markdown]
# ## Máximo

# %%
ma = df.max ()

# %%
print (ma)
# Out:
# artists              $0dg0d
# acousticness          0.927
# danceability          0.734
# duration_ms          328920
# energy                0.822
# instrumentalness      0.186
# liveness              0.737
# loudness             -5.387
# speechiness           0.256
# tempo               141.948
# valence               0.902
# popularity               42
# key                      10
# mode                      1
# count                   106
# dtype: object

# %% [markdown]
# ## relación lineal positiva

# %%
sns.pairplot(relacion, kind ='reg')

# %% [raw]
# para mi el tempo-count y el key-count son los que son o tienen una relacion lineal positiva, ambas gráficas se presentan de igual manera
