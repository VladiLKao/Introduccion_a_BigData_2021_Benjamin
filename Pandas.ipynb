# %% [markdown]
# # pandas
# es una librereria de python para analizar Data Frames
# ##numpy

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    NaN
# 6    6.0
# 7    8.0
# dtype: float64

# %%
dates = pd.date_range('20150101', periods=60)
dates
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10', '2015-01-11', '2015-01-12',
#                '2015-01-13', '2015-01-14', '2015-01-15', '2015-01-16',
#                '2015-01-17', '2015-01-18', '2015-01-19', '2015-01-20',
#                '2015-01-21', '2015-01-22', '2015-01-23', '2015-01-24',
#                '2015-01-25', '2015-01-26', '2015-01-27', '2015-01-28',
#                '2015-01-29', '2015-01-30', '2015-01-31', '2015-02-01',
#                '2015-02-02', '2015-02-03', '2015-02-04', '2015-02-05',
#                '2015-02-06', '2015-02-07', '2015-02-08', '2015-02-09',
#                '2015-02-10', '2015-02-11', '2015-02-12', '2015-02-13',
#                '2015-02-14', '2015-02-15', '2015-02-16', '2015-02-17',
#                '2015-02-18', '2015-02-19', '2015-02-20', '2015-02-21',
#                '2015-02-22', '2015-02-23', '2015-02-24', '2015-02-25',
#                '2015-02-26', '2015-02-27', '2015-02-28', '2015-03-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pandas_dates = pd.DataFrame({'dates_column':dates})

# %%
pandas_dates.head(5)
# Out:
#   dates_column
# 0   2015-01-01
# 1   2015-01-02
# 2   2015-01-03
# 3   2015-01-04
# 4   2015-01-05

# %%
type(pandas_dates)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.DataFrame({'Numero':1,
                    'Fecha':pd.date_range('2014',periods=4),
                    'Rango':pd.Series(1, index=list(range(4)), dtype='float32'),
                    'Flotante': np.array([3]*4, dtype='float32'),
                    'Lista': pd.Categorical(['test','train','try','test']),
                    'String': 'foo'})

# %%
df2.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Numero    4 non-null      int64
#  1   Fecha     4 non-null      datetime64[ns]
#  2   Rango     4 non-null      float32
#  3   Flotante  4 non-null      float32
#  4   Lista     4 non-null      category
#  5   String    4 non-null      object
# dtypes: category(1), datetime64[ns](1), float32(2), int64(1), object(1)
# memory usage: 268.0+ bytes

# %%
df2.dtypes
# Out:
# Numero               int64
# Fecha       datetime64[ns]
# Rango              float32
# Flotante           float32
# Lista             category
# String              object
# dtype: object

# %%
df2.head(3)
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 0       1 2014-01-01    1.0       3.0   test    foo
# 1       1 2014-01-02    1.0       3.0  train    foo
# 2       1 2014-01-03    1.0       3.0    try    foo

# %%
df2.tail(3)
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 1       1 2014-01-02    1.0       3.0  train    foo
# 2       1 2014-01-03    1.0       3.0    try    foo
# 3       1 2014-01-04    1.0       3.0   test    foo

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df2.columns
# Out:
# Index(['Numero', 'Fecha', 'Rango', 'Flotante', 'Lista', 'String'], dtype='object')

# %%
 df2.describe()
# Out:
#        Numero  Rango  Flotante
# count     4.0    4.0       4.0
# mean      1.0    1.0       3.0
# std       0.0    0.0       0.0
# min       1.0    1.0       3.0
# 25%       1.0    1.0       3.0
# 50%       1.0    1.0       3.0
# 75%       1.0    1.0       3.0
# max       1.0    1.0       3.0

# %%
df2.corr()
# Out:
#           Numero  Rango  Flotante
# Numero       NaN    NaN       NaN
# Rango        NaN    NaN       NaN
# Flotante     NaN    NaN       NaN

# %%
df2.T
# Out:
#                             0                    1                    2  \
# Numero                      1                    1                    1
# Fecha     2014-01-01 00:00:00  2014-01-02 00:00:00  2014-01-03 00:00:00
# Rango                       1                    1                    1
# Flotante                    3                    3                    3
# Lista                    test                train                  try
# String                    foo                  foo                  foo
#
#                             3
# Numero                      1
# Fecha     2014-01-04 00:00:00
# Rango                       1
# Flotante                    3
# Lista                    test
# String                    foo

# %%
df2.t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-6ec28cbcaa25> in <module>
# ----> 1 df2.t
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 't'

# %%
df2.T
# Out:
#                             0                    1                    2  \
# Numero                      1                    1                    1
# Fecha     2014-01-01 00:00:00  2014-01-02 00:00:00  2014-01-03 00:00:00
# Rango                       1                    1                    1
# Flotante                    3                    3                    3
# Lista                    test                train                  try
# String                    foo                  foo                  foo
#
#                             3
# Numero                      1
# Fecha     2014-01-04 00:00:00
# Rango                       1
# Flotante                    3
# Lista                    test
# String                    foo

# %%
df2.head(3)
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 0       1 2014-01-01    1.0       3.0   test    foo
# 1       1 2014-01-02    1.0       3.0  train    foo
# 2       1 2014-01-03    1.0       3.0    try    foo

# %%
df2.sort_values(by='Lista')
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 0       1 2014-01-01    1.0       3.0   test    foo
# 3       1 2014-01-04    1.0       3.0   test    foo
# 1       1 2014-01-02    1.0       3.0  train    foo
# 2       1 2014-01-03    1.0       3.0    try    foo

# %%
pd = pd.DataFrame(np.random.randn(60,4), 
index=dates, columns=('ABCD'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-e37e44f84a01> in <module>
#       1 pd = pd.DataFrame(np.random.randn(60,4),
# ----> 2 index=dates, columns=('ABCD'))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     462                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     463             else:
# --> 464                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     465
#     466         # For data is list-like, or Iterable (will consume into list)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     179                 ) from orig
#     180
# --> 181     index, columns = _get_axes(*values.shape, index=index, columns=columns)
#     182     values = values.T
#     183
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/construction.py in _get_axes(N, K, index, columns)
#     427         columns = ibase.default_index(K)
#     428     else:
# --> 429         columns = ensure_index(columns)
#     430     return index, columns
#     431
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5356             index_like = copy(index_like)
#    5357
# -> 5358     return Index(index_like)
#    5359
#    5360
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     420             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#     421         elif data is None or is_scalar(data):
# --> 422             raise cls._scalar_data_error(data)
#     423         else:
#     424             if tupleize_cols and is_list_like(data):
#
# TypeError: Index(...) must be called with a collection of some kind, 'ABCD' was passed

# %%
pd = pd.DataFrame(np.random.randn(60,4), index=dates, columns=list('ABCD'))

# %%
pd
# Out:
#                    A         B         C         D
# 2015-01-01  0.469962  0.741536 -0.309442 -0.500648
# 2015-01-02  0.265166  1.138399 -0.227334 -0.974819
# 2015-01-03  0.288309  1.972574  0.992027  1.187659
# 2015-01-04 -0.968127 -1.614156 -0.695505  0.303525
# 2015-01-05 -0.271566 -0.628463  1.038369 -0.959966
# 2015-01-06  1.479699  0.498947 -2.194043 -0.749020
# 2015-01-07 -0.638014 -0.774191  0.210010  0.989116
# 2015-01-08  1.120301  0.412266  1.715465  0.768667
# 2015-01-09  0.901339 -0.225974 -0.225329  0.482889
# 2015-01-10  0.526382  2.146505  0.017718  0.066051
# 2015-01-11 -0.886310  0.550241 -0.525340 -0.154165
# 2015-01-12 -0.579342  0.543210  0.278159 -0.605252
# 2015-01-13 -1.405903 -1.693908  0.041369 -1.811086
# 2015-01-14 -1.437909  0.987035  1.824232  0.316667
# 2015-01-15 -0.094356 -0.320183  0.038652 -0.336477
# 2015-01-16 -0.700913 -0.447212 -0.001965  1.740610
# 2015-01-17  0.495558 -0.683571 -2.183764  1.175665
# 2015-01-18  0.381400  0.800958  0.108590 -0.591337
# 2015-01-19 -0.190355 -0.707234  0.397711 -0.590386
# 2015-01-20  0.492534 -0.044248 -1.915833  0.959395
# 2015-01-21 -0.164697 -1.262611  2.516074  0.397750
# 2015-01-22 -0.667883 -0.282389  0.967298  0.998931
# 2015-01-23  0.263557  0.267785 -0.746388  0.720701
# 2015-01-24 -1.495654  0.243734 -0.101054  0.279315
# 2015-01-25 -0.731944 -0.993058 -1.536721 -0.446691
# 2015-01-26  0.866889  1.067666 -0.076036  2.011479
# 2015-01-27  0.875799  0.242043  0.829515  1.878657
# 2015-01-28  1.487923 -0.676621  0.420400 -0.224676
# 2015-01-29 -0.183053  0.857202  0.451976 -0.548305
# 2015-01-30  0.357511 -0.889051 -1.196739  1.057768
# 2015-01-31 -1.858888 -1.266090 -0.709227  0.200609
# 2015-02-01  0.290784 -0.346991 -1.876819  0.431126
# 2015-02-02 -0.595787  0.031678 -0.514432 -0.146099
# 2015-02-03 -1.263642  0.235832 -0.252285  0.740196
# 2015-02-04  0.072564  1.371070 -0.348045  0.528149
# 2015-02-05 -0.529648  1.418421 -0.745583 -0.512601
# 2015-02-06 -0.080467 -0.350734  1.838789  1.225453
# 2015-02-07  1.221716 -0.506378 -0.325478 -1.240927
# 2015-02-08  2.046901  0.627978 -0.451607  0.030644
# 2015-02-09 -1.894359  1.011243  0.959217  0.623118
# 2015-02-10 -1.556113  0.635809 -0.599678  0.218310
# 2015-02-11 -0.442571 -0.604077  0.895105 -0.082934
# 2015-02-12  0.193214 -1.451984 -1.780628  0.059572
# 2015-02-13 -1.118981 -0.789063  0.339258 -0.725096
# 2015-02-14 -0.376327 -1.135584 -1.956707  0.009091
# 2015-02-15  1.107921  0.929466 -1.257125 -0.782922
# 2015-02-16  1.267717 -1.089624  0.616256 -0.312145
# 2015-02-17  0.074438 -1.966575 -0.571819  0.809698
# 2015-02-18 -0.570488  0.534331  0.483230 -0.107842
# 2015-02-19  1.422056  0.518706 -0.684665 -1.127826
# 2015-02-20 -0.528768  1.505578 -0.415389  0.372614
# 2015-02-21  0.381372 -0.394858  0.977653 -0.800938
# 2015-02-22  1.437561 -0.710296 -0.138360  1.137296
# 2015-02-23 -1.197265  1.992160  0.648090 -1.782666
# 2015-02-24 -0.192612 -0.144735 -0.720402  1.237423
# 2015-02-25 -0.129908  1.313929  0.197108 -0.664191
# 2015-02-26  1.869510  0.560894  0.827198  2.712139
# 2015-02-27  0.433194  1.544759 -0.540685  0.345407
# 2015-02-28 -0.489458  2.100777 -0.750400  0.660772
# 2015-03-01  0.251377  1.192725  0.870998 -0.130697

# %%
pd.head(5)
# Out:
#                    A         B         C         D
# 2015-01-01  0.469962  0.741536 -0.309442 -0.500648
# 2015-01-02  0.265166  1.138399 -0.227334 -0.974819
# 2015-01-03  0.288309  1.972574  0.992027  1.187659
# 2015-01-04 -0.968127 -1.614156 -0.695505  0.303525
# 2015-01-05 -0.271566 -0.628463  1.038369 -0.959966

# %%
import pandas as pd
import numpy as np

# %%
random = pd.DataFrame(np.random.randn(60,4), index=dates, columns=list('ABCD'))

# %%
pd.random(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-619da7ea2229> in <module>
# ----> 1 pd.random(5)
#
# AttributeError: module 'pandas' has no attribute 'random'

# %%
import pandas as pd
import numpy as np

# %%
random = pd.DataFrame(np.random.randn(60,4), index=dates, columns=list('ABCD'))

# %%
pd.random(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-619da7ea2229> in <module>
# ----> 1 pd.random(5)
#
# AttributeError: module 'pandas' has no attribute 'random'

# %%
random.head(5)
# Out:
#                    A         B         C         D
# 2015-01-01  0.386097 -0.498659  0.490336  1.009029
# 2015-01-02 -0.350873 -0.569751  0.110991  0.284029
# 2015-01-03 -1.275913 -0.618553  0.880108 -0.374751
# 2015-01-04 -0.187631  1.203830  0.934395  0.977603
# 2015-01-05 -0.800299  0.136093  0.919169 -0.118600

# %%
random.loc[:, ['A','B']]
# Out:
#                    A         B
# 2015-01-01  0.386097 -0.498659
# 2015-01-02 -0.350873 -0.569751
# 2015-01-03 -1.275913 -0.618553
# 2015-01-04 -0.187631  1.203830
# 2015-01-05 -0.800299  0.136093
# 2015-01-06  0.492929 -0.635753
# 2015-01-07 -0.481477  0.570786
# 2015-01-08 -2.037289 -0.543004
# 2015-01-09  0.737005 -0.333087
# 2015-01-10  0.575851 -0.738383
# 2015-01-11  1.390674 -0.388908
# 2015-01-12 -0.269574 -0.319866
# 2015-01-13 -1.150767 -0.056357
# 2015-01-14  0.579685 -1.261642
# 2015-01-15 -1.644349  0.051976
# 2015-01-16 -0.637521 -0.127541
# 2015-01-17  1.334910  1.394515
# 2015-01-18  0.293805 -0.240903
# 2015-01-19 -1.623278 -0.232644
# 2015-01-20  1.811347 -0.113728
