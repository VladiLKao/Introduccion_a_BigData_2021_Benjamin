# %%
import pandas as pd

df = pd.read_csv('https://testutmbenjamin.s3.amazonaws.com/MOCK_DATA.csv')

# %%
df
# Out:
#        id  first_name last_name                             email  gender  \
# 0       1        Kipp   Leibold             kleibold0@typepad.com  Female
# 1       2         Dar      Dawe                 ddawe1@scribd.com    Male
# 2       3       Lizzy     Stacy                lstacy2@weebly.com  Female
# 3       4      Idalia    Gandar        igandar3@blogtalkradio.com  Female
# 4       5   Bartolemo   Zettler             bzettler4@spotify.com    Male
# ..    ...         ...       ...                               ...     ...
# 995   996       Hagen     Sawer                  hsawerrn@usa.gov    Male
# 996   997     Shirlee  Eskriett              seskriettro@about.me  Female
# 997   998  Margaretha   Wohlers         mwohlersrp@vistaprint.com  Female
# 998   999   Celestine  Penniell  cpenniellrq@pagesperso-orange.fr  Female
# 999  1000      Evelin     Berni                ebernirr@wiley.com    Male
#
#          ip_address
# 0    133.162.152.13
# 1    186.36.177.240
# ...

# %%
import pandas as pd
df = pd.read_csv('https://testutmbenjamin.s3.amazonaws.com/MOCK_DATA.csv')

# %%
df
# Out:
#        id  first_name last_name                             email  gender  \
# 0       1        Kipp   Leibold             kleibold0@typepad.com  Female
# 1       2         Dar      Dawe                 ddawe1@scribd.com    Male
# 2       3       Lizzy     Stacy                lstacy2@weebly.com  Female
# 3       4      Idalia    Gandar        igandar3@blogtalkradio.com  Female
# 4       5   Bartolemo   Zettler             bzettler4@spotify.com    Male
# ..    ...         ...       ...                               ...     ...
# 995   996       Hagen     Sawer                  hsawerrn@usa.gov    Male
# 996   997     Shirlee  Eskriett              seskriettro@about.me  Female
# 997   998  Margaretha   Wohlers         mwohlersrp@vistaprint.com  Female
# 998   999   Celestine  Penniell  cpenniellrq@pagesperso-orange.fr  Female
# 999  1000      Evelin     Berni                ebernirr@wiley.com    Male
#
#          ip_address
# 0    133.162.152.13
# 1    186.36.177.240
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://datautmexample.s3.amazonaws.com/COVID-19_Case_Surveillance_Public_Use_Data.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-32-ee3351d9b63e> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df = pd.read_csv('https://datautmexample.s3.amazonaws.com/COVID-19_Case_Surveillance_Public_Use_Data.csv')
#
# ...

# %%
df
# Out:
#         cdc_report_dt pos_spec_dt    onset_dt             current_status  \
# 0          2020/11/10  2020/11/10         NaN  Laboratory-confirmed case
# 1          2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case
# 2          2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case
# 3          2020/11/14  2020/11/10         NaN  Laboratory-confirmed case
# 4          2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case
# ...               ...         ...         ...                        ...
# 8405074    2020/10/22         NaN         NaN              Probable Case
# 8405075    2020/10/25         NaN         NaN  Laboratory-confirmed case
# 8405076    2020/07/18         NaN         NaN  Laboratory-confirmed case
# 8405077    2020/11/19         NaN         NaN  Laboratory-confirmed case
# 8405078    2020/11/03         NaN         NaN  Laboratory-confirmed case
#
#              sex      age_group Race and ethnicity (combined)  hosp_yn  \
# ...

# %%
df.head (3)
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
#
#        age_group Race and ethnicity (combined) hosp_yn   icu_yn death_yn  \
# 0  10 - 19 Years           Black, Non-Hispanic      No  Unknown       No
# 1  10 - 19 Years           Black, Non-Hispanic      No       No       No
# 2  10 - 19 Years           Black, Non-Hispanic      No       No       No
#
#   medcond_yn
# 0         No
# 1         No
# 2         No

# %%
df.head (11)
# Out:
#     id first_name     last_name                       email  gender  \
# 0    1       Kipp       Leibold       kleibold0@typepad.com  Female
# 1    2        Dar          Dawe           ddawe1@scribd.com    Male
# 2    3      Lizzy         Stacy          lstacy2@weebly.com  Female
# 3    4     Idalia        Gandar  igandar3@blogtalkradio.com  Female
# 4    5  Bartolemo       Zettler       bzettler4@spotify.com    Male
# 5    6    Alberto      Casarini          acasarini5@ted.com    Male
# 6    7      Torie    Castletine       tcastletine6@noaa.gov  Female
# 7    8       Robb        Cassin         rcassin7@usnews.com    Male
# 8    9      Udell       Mummery            umummery8@wp.com    Male
# 9   10        Fay  MacConnechie      fmacconnechie9@ftc.gov  Female
# 10  11      Emmit         Bryer  ebryera@simplemachines.org    Male
#
#         ip_address
# 0   133.162.152.13
# 1   186.36.177.240
# 2    11.202.224.20
# 3     59.81.46.238
# 4    69.103.158.98
# 5   236.190.21.244
# ...

# %%
data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8405079 entries, 0 to 8405078
# Data columns (total 11 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   cdc_report_dt                  object
#  1   pos_spec_dt                    object
#  2   onset_dt                       object
#  3   current_status                 object
#  4   sex                            object
#  5   age_group                      object
#  6   Race and ethnicity (combined)  object
#  7   hosp_yn                        object
#  8   icu_yn                         object
#  9   death_yn                       object
#  10  medcond_yn                     object
# dtypes: object(11)
# memory usage: 705.4+ MB

# %%
df.describe ()
# Out:
#        cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# count              3           3           2                          3     3
# unique             3           1           2                          1     1
# top       2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
# freq               1           3           1                          3     3
#
#             age_group Race and ethnicity (combined) hosp_yn icu_yn death_yn  \
# count               3                             3       3      3        3
# unique              1                             1       1      2        1
# top     10 - 19 Years           Black, Non-Hispanic      No     No       No
# freq                3                             3       3      2        3
#
#        medcond_yn
# count           3
# unique          1
# top            No
# freq            3

# %%
df = df.head(3).sort_values(by='current_status')

# %%
df.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dates = pd.date_range('20150101', periods=60)
dates
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10', '2015-01-11', '2015-01-12',
#                '2015-01-13', '2015-01-14', '2015-01-15', '2015-01-16',
#                '2015-01-17', '2015-01-18', '2015-01-19', '2015-01-20',
#                '2015-01-21', '2015-01-22', '2015-01-23', '2015-01-24',
#                '2015-01-25', '2015-01-26', '2015-01-27', '2015-01-28',
#                '2015-01-29', '2015-01-30', '2015-01-31', '2015-02-01',
#                '2015-02-02', '2015-02-03', '2015-02-04', '2015-02-05',
#                '2015-02-06', '2015-02-07', '2015-02-08', '2015-02-09',
#                '2015-02-10', '2015-02-11', '2015-02-12', '2015-02-13',
#                '2015-02-14', '2015-02-15', '2015-02-16', '2015-02-17',
#                '2015-02-18', '2015-02-19', '2015-02-20', '2015-02-21',
# ...

# %%
pandas_dates = pd.DataFrame({'dates_column':dates})

# %%
pandas_dates.head(5)
# Out:
#   dates_column
# 0   2015-01-01
# 1   2015-01-02
# 2   2015-01-03
# 3   2015-01-04
# 4   2015-01-05

# %%
pandas_dates.head(10)
# Out:
#   dates_column
# 0   2015-01-01
# 1   2015-01-02
# 2   2015-01-03
# 3   2015-01-04
# 4   2015-01-05
# 5   2015-01-06
# 6   2015-01-07
# 7   2015-01-08
# 8   2015-01-09
# 9   2015-01-10

# %%
df2 = pd.DataFrame({'Numero':1,
                    'Fecha':pd.date_range('2014',periods=4),
                    'Rango':pd.Series(1, index=list(range(4)), dtype='float32'),
                    'Flotante': np.array([3]*4, dtype='float32'),
                    'Lista': pd.Categorical(['test','train','try','test']),
                    'String': 'foo'})

# %%
df2.dtypes

# %%
df.head (10)
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
#
#        age_group Race and ethnicity (combined) hosp_yn   icu_yn death_yn  \
# 0  10 - 19 Years           Black, Non-Hispanic      No  Unknown       No
# 1  10 - 19 Years           Black, Non-Hispanic      No       No       No
# 2  10 - 19 Years           Black, Non-Hispanic      No       No       No
#
#   medcond_yn
# 0         No
# 1         No
# 2         No

# %%
df2.head (2)
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 0       1 2014-01-01    1.0       3.0   test    foo
# 1       1 2014-01-02    1.0       3.0  train    foo

# %%
df2.head (5)
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 0       1 2014-01-01    1.0       3.0   test    foo
# 1       1 2014-01-02    1.0       3.0  train    foo
# 2       1 2014-01-03    1.0       3.0    try    foo
# 3       1 2014-01-04    1.0       3.0   test    foo

# %%
relation = df [['age_group','cdc_report_dt','current_status', 'sex']]

# %%
relation.head (5)
# Out:
#        age_group cdc_report_dt             current_status   sex
# 0  10 - 19 Years    2020/11/10  Laboratory-confirmed case  Male
# 1  10 - 19 Years    2020/11/14  Laboratory-confirmed case  Male
# 2  10 - 19 Years    2020/11/19  Laboratory-confirmed case  Male

# %%
relation.head (10)
# Out:
#        age_group cdc_report_dt             current_status   sex
# 0  10 - 19 Years    2020/11/10  Laboratory-confirmed case  Male
# 1  10 - 19 Years    2020/11/14  Laboratory-confirmed case  Male
# 2  10 - 19 Years    2020/11/19  Laboratory-confirmed case  Male

# %%
relation2 = df [['pos_spec_dt','cdc_report_dt']]

# %%
relation2.head (5)
# Out:
#   pos_spec_dt cdc_report_dt
# 0  2020/11/10    2020/11/10
# 1  2020/11/10    2020/11/14
# 2  2020/11/10    2020/11/19

# %%
df2.tail(3)
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 1       1 2014-01-02    1.0       3.0  train    foo
# 2       1 2014-01-03    1.0       3.0    try    foo
# 3       1 2014-01-04    1.0       3.0   test    foo

# %%
df2.T
# Out:
#                             0                    1                    2  \
# Numero                      1                    1                    1
# Fecha     2014-01-01 00:00:00  2014-01-02 00:00:00  2014-01-03 00:00:00
# Rango                       1                    1                    1
# Flotante                    3                    3                    3
# Lista                    test                train                  try
# String                    foo                  foo                  foo
#
#                             3
# Numero                      1
# Fecha     2014-01-04 00:00:00
# Rango                       1
# Flotante                    3
# Lista                    test
# String                    foo

# %%
df2.sort_values(by='Lista')
# Out:
#    Numero      Fecha  Rango  Flotante  Lista String
# 0       1 2014-01-01    1.0       3.0   test    foo
# 3       1 2014-01-04    1.0       3.0   test    foo
# 1       1 2014-01-02    1.0       3.0  train    foo
# 2       1 2014-01-03    1.0       3.0    try    foo

# %%
pd = pd.DataFrame(np.random.randn(60,4), index=dates, columns=list('ABCD'))

# %%
pd
# Out:
#                    A         B         C         D
# 2015-01-01 -1.389367  0.935090 -2.178782 -0.116734
# 2015-01-02 -1.176546 -0.054414 -0.056881 -1.578432
# 2015-01-03  0.380613  0.027551  1.637818  1.470281
# 2015-01-04 -0.280776  0.561263  0.261033  2.423338
# 2015-01-05 -0.329082  1.498322  0.938203  1.434917
# 2015-01-06 -0.560333  0.610899 -0.716986  0.234320
# 2015-01-07  0.965053  0.339027 -0.106800 -0.939867
# 2015-01-08 -0.801253 -0.434608 -2.503384  0.725373
# 2015-01-09  1.337792  0.098224 -0.627036  0.664103
# 2015-01-10  1.371404 -1.000775 -1.167882 -0.917786
# 2015-01-11  1.425332  0.759465 -0.021791 -0.765713
# 2015-01-12  0.128514  0.579508 -0.550642 -3.220054
# 2015-01-13 -0.339610  0.578469 -1.427843  3.076553
# 2015-01-14 -0.171452 -0.351457  0.134826 -1.242516
# 2015-01-15  0.922402 -0.000204  0.885802  0.041747
# 2015-01-16 -0.301982  0.530244 -0.250543  0.647961
# 2015-01-17 -1.620666 -0.422769 -1.133941 -0.075456
# ...

# %%
import pandas as pd
import numpy as np

# %%
random = pd.DataFrame(np.random.randn(60,4), index=dates, columns=list('ABCD'))

# %%
random.head(10)
# Out:
#                    A         B         C         D
# 2015-01-01  0.300668  1.200404 -0.031822  0.826172
# 2015-01-02  1.317767  1.753211  0.981275 -0.395366
# 2015-01-03  0.089255  0.681492 -0.116533  0.947523
# 2015-01-04 -1.235742  0.671591  0.697281  0.144990
# 2015-01-05  0.541672 -1.109721  1.628763  1.402423
# 2015-01-06  0.824180 -0.184383 -1.924292  1.851429
# 2015-01-07  0.032693 -0.562609 -1.674449 -0.176783
# 2015-01-08 -0.590963  0.184795  0.061427  1.765647
# 2015-01-09 -0.097692 -0.980150  1.858982 -0.296396
# 2015-01-10  0.128175 -0.695821  0.746351  0.082534

# %%
random.loc[:, ['A','B']]
# Out:
#                    A         B
# 2015-01-01  0.300668  1.200404
# 2015-01-02  1.317767  1.753211
# 2015-01-03  0.089255  0.681492
# 2015-01-04 -1.235742  0.671591
# 2015-01-05  0.541672 -1.109721
# 2015-01-06  0.824180 -0.184383
# 2015-01-07  0.032693 -0.562609
# 2015-01-08 -0.590963  0.184795
# 2015-01-09 -0.097692 -0.980150
# 2015-01-10  0.128175 -0.695821
# 2015-01-11 -1.171016  0.563863
# 2015-01-12  1.636315  0.068100
# 2015-01-13 -0.727650  0.117128
# 2015-01-14 -0.605570  1.315020
# 2015-01-15 -1.617183  1.214435
# 2015-01-16 -0.641243  0.490119
# 2015-01-17  0.580474 -0.087917
# 2015-01-18  1.068641  1.097238
# 2015-01-19 -0.330201  0.568942
# 2015-01-20 -0.184896 -1.127717
# 2015-01-21 -1.190377  0.228209
# 2015-01-22  0.178442  0.919330
# 2015-01-23  0.492565  1.540298
# 2015-01-24  2.889371 -0.829230
# 2015-01-25  0.890483 -1.361337
# 2015-01-26 -0.600692  0.004259
# 2015-01-27  0.176731 -1.314342
# 2015-01-28  0.090054 -1.518636
# 2015-01-29  0.041111 -0.281892
# ...

# %%
random.loc['2015-01-01':'2015-01-15', ['A','B']]
# Out:
#                    A         B
# 2015-01-01  0.300668  1.200404
# 2015-01-02  1.317767  1.753211
# 2015-01-03  0.089255  0.681492
# 2015-01-04 -1.235742  0.671591
# 2015-01-05  0.541672 -1.109721
# 2015-01-06  0.824180 -0.184383
# 2015-01-07  0.032693 -0.562609
# 2015-01-08 -0.590963  0.184795
# 2015-01-09 -0.097692 -0.980150
# 2015-01-10  0.128175 -0.695821
# 2015-01-11 -1.171016  0.563863
# 2015-01-12  1.636315  0.068100
# 2015-01-13 -0.727650  0.117128
# 2015-01-14 -0.605570  1.315020
# 2015-01-15 -1.617183  1.214435

# %%
random.loc['2015-01-01':'2015-01-15', ['C','D']]
# Out:
#                    C         D
# 2015-01-01 -0.031822  0.826172
# 2015-01-02  0.981275 -0.395366
# 2015-01-03 -0.116533  0.947523
# 2015-01-04  0.697281  0.144990
# 2015-01-05  1.628763  1.402423
# 2015-01-06 -1.924292  1.851429
# 2015-01-07 -1.674449 -0.176783
# 2015-01-08  0.061427  1.765647
# 2015-01-09  1.858982 -0.296396
# 2015-01-10  0.746351  0.082534
# 2015-01-11 -1.661587  0.332004
# 2015-01-12 -0.315851  0.558489
# 2015-01-13  0.296036 -0.303749
# 2015-01-14 -0.520579 -1.692736
# 2015-01-15 -0.556235 -1.041944

# %%
history
# Out:
# import pandas as pd
#
# df = pd.read_csv('https://testutmbenjamin.s3.amazonaws.com/MOCK_DATA.csv')
# df
# import pandas as pd
# df = pd.read_csv('https://testutmbenjamin.s3.amazonaws.com/MOCK_DATA.csv')
# df
# import pandas as pd
# data = pd.read_csv('https://datautmexample.s3.amazonaws.com/COVID-19_Case_Surveillance_Public_Use_Data.csv')
# data
# data.head (3)
# df.head (11)
# data.info ()
# data.describe ()
# data.describe ()
# data = data.head(50).sort_values(by='current_status')
# data = data.head(10).sort_values(by='current_status')
# data.corr()
# df.corr()
# df = df.head(10).sort_values(by='current_status')
# data.describe ()
# df = df.head(3).sort_values(by='current_status')
# data = data.head(3).sort_values(by='current_status')
# import pandas as pd
# df = pd.read_csv('https://datautmexample.s3.amazonaws.com/COVID-19_Case_Surveillance_Public_Use_Data.csv')
# df = df.head(3).sort_values(by='current_status')
# df.corr()
# df.describe ()
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-782585e920e5> in <module>
# ----> 1 sns.pairplot(relation, kind='reg')
#       2 plt.show()
#
# NameError: name 'sns' is not defined
